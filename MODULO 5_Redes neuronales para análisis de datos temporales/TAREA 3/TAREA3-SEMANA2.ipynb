# %%
import pandas as pd
import numpy as np #para manejar las listas obtenidas
import json
import matplotlib.pyplot as plt

data=pd.read_csv("data1.csv")
data.columns = ['Columna1','Columna2','Columna3','Columna4','Columna5','Columna6','Columna7','Columna8','Columna9','Columna10','Columna11','Columna12','Columna13','Columna14','Columna15','Columna16','Columna17','Columna18','Columna19','Columna20','Columna21','Columna22','Columna23','Columna24']
data.head()
# Out:
#    Columna1  Columna2  Columna3  Columna4  Columna5  Columna6  Columna7  \
# 0   -9.8489   0.52404   0.37348  0.004186  0.016745    2.3876   -9.5080
# 1   -9.6602   0.18185   0.43742  0.016745  0.037677    2.4086   -9.5674
# 2   -9.6507   0.21422   0.24033  0.079540  0.117220    2.1814   -9.4301
# 3   -9.7030   0.30389   0.31156  0.221870  0.205130    2.4173   -9.3889
# 4   -9.6511   0.23261   0.42094  0.154890  0.138150    2.2639   -9.4493
#
#    Columna8  Columna9  Columna10  ...  Columna15  Columna16  Columna17  \
# 0   0.68389  0.085343   -0.83865  ...    -8.6275    -4.3198   0.023595
# 1   0.68113  0.085343   -0.83865  ...    -8.5055    -4.2772   0.275720
# 2   0.55031  0.085343   -0.83865  ...    -8.6279    -4.3163   0.367520
# 3   0.71098  0.085343   -0.83865  ...    -8.7008    -4.1459   0.407290
# 4   0.61267  0.098330   -0.84240  ...    -8.7247    -4.0449   0.506090
#
#    Columna18  Columna19  Columna20  Columna21  Columna22  Columna23  Columna24
# 0   -0.44902    -1.0103   0.034483   -2.16320  -0.882540   0.326570          0
# 1   -0.44902    -1.0103   0.034483   -1.61750  -0.165620  -0.030693          0
# 2   -0.45686    -1.0082   0.025862   -1.07710   0.006945  -0.382620          0
# 3   -0.45686    -1.0082   0.025862   -0.53684   0.175900  -1.095500          0
# 4   -0.45686    -1.0082   0.025862    0.18674   0.720440  -0.364480          0
#
# [5 rows x 24 columns]

# %%
dataCardio= data[["Columna4","Columna5"]]

def añadirTiempo(data):
    data['NuevoTiempo']=data[data.columns].mean(axis=1) 
    return data

#dataCardio=añadirTiempo(dataCardio)
dataCardio.head()
# Out:
#    Columna4  Columna5
# 0  0.004186  0.016745
# 1  0.016745  0.037677
# 2  0.079540  0.117220
# 3  0.221870  0.205130
# 4  0.154890  0.138150

# %%
def aumentarDimension(dataframe):
    return dataframe.values.reshape(dataframe.shape[0],dataframe.shape[1],1)

# %%
dataCardioT=aumentarDimension(dataCardio)
dataCardioT.shape
# Out:
# (161279, 2, 1)

# %%
plt.plot(dataCardioT[1],dataCardioT[0])
plt.ylabel('data cardio')
plt.show()
