# %%
import  pandas as pd
import numpy as np
from plotnine import *

import os

# %%
df=pd.read_csv("raw_fighter_details.csv")

# %%
df.head(10)
# Out:
#       fighter_name  Height    Weight Reach    Stance           DOB
# 0       AJ Fonseca   5' 4"  145 lbs.   NaN       NaN           NaN
# 1      AJ Matthews  5' 11"  185 lbs.   NaN       NaN           NaN
# 2         AJ McKee  5' 10"  145 lbs.   NaN       NaN           NaN
# 3        AJ Siscoe   5' 7"  135 lbs.   NaN       NaN           NaN
# 4       Aalon Cruz   6' 0"  145 lbs.   NaN       NaN           NaN
# 5      Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 6        Aaron Ely   5' 8"  135 lbs.   NaN       NaN  Mar 18, 1989
# 7    Aaron Jeffery   6' 2"  185 lbs.   NaN       NaN  Nov 14, 1992
# 8  Aaron Lanfranco     NaN  155 lbs.   NaN       NaN  Aug 26, 1986
# 9     Aaron Miller   5' 9"  145 lbs.   NaN       NaN           NaN

# %%
list(df)
# Out:
# ['fighter_name', 'Height', 'Weight', 'Reach', 'Stance', 'DOB']

# %%
df=df.dropna()

# %%
df.head()
# Out:
#             fighter_name  Height    Weight Reach    Stance           DOB
# 10        Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11           Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12            Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13         Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 17  Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985

# %%
(ggplot(df)
  + aes('fighter_name', 'Weight')
   + geom_point())
# Out:
# <ggplot: (-9223371896520833568)>

# %%
df2=pd.read_csv("raw_total_fight_data.csv")

# %% [markdown]
# df2=df2.dropna()

# %%
df2=df2.dropna()

# %%
df2.head()
# Out:
#                                                                            R_fighter;B_fighter;R_KD;B_KD;R_SIG_STR.;B_SIG_STR.;R_SIG_STR_pct;B_SIG_STR_pct;R_TOTAL_STR.;B_TOTAL_STR.;R_TD;B_TD;R_TD_pct;B_TD_pct;R_SUB_ATT;B_SUB_ATT;R_PASS;B_PASS;R_REV;B_REV;R_HEAD;B_HEAD;R_BODY;B_BODY;R_LEG;B_LEG;R_DISTANCE;B_DISTANCE;R_CLINCH;B_CLINCH;R_GROUND;B_GROUND;win_by;last_round;last_round_time;Format;Referee;date;location;Fight_type;Winner
# Henry Cejudo;Marlon Moraes;0;0;90 of 171;57 of ...  2019;Chicago  Illinois       USA;UFC Bantamweight Title Bout;Henry Cejudo
# Valentina Shevchenko;Jessica Eye;1;0;8 of 11;2 ...  2019;Chicago  Illinois   USA;UFC Women's Flyweight Title Bout;Valentin...
# Tony Ferguson;Donald Cerrone;0;0;104 of 200;68 ...  2019;Chicago  Illinois                 USA;Lightweight Bout;Tony Ferguson
# Jimmie Rivera;Petr Yan;0;2;73 of 192;56 of 189;...  2019;Chicago  Illinois                     USA;Bantamweight Bout;Petr Yan
# ...
